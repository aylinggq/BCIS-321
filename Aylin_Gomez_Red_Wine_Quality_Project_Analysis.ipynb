# %%
import pandas as pd
url= ('https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv')
df = pd.read_csv(url, sep=';')

# %%
#How many rows and columns are in the data?
df.shape
# Out:
# (1599, 12)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#df.duplicated().sum()
df[df.duplicated()]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 11              7.5             0.500         0.36            6.10      0.071
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# ...             ...               ...          ...             ...        ...
# 1563            7.2             0.695         0.13            2.00      0.076
# 1564            7.2             0.695         0.13            2.00      0.076
# 1567            7.2             0.695         0.13            2.00      0.076
# 1581            6.2             0.560         0.09            1.70      0.053
# 1596            6.3             0.510         0.13            2.30      0.076
#
# ...

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
count = (df['quality'] == 8).sum()
print(count)
# Out:
# 17

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1359 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1359 non-null   float64
#  1   volatile acidity      1359 non-null   float64
#  2   citric acid           1359 non-null   float64
#  3   residual sugar        1359 non-null   float64
#  4   chlorides             1359 non-null   float64
#  5   free sulfur dioxide   1359 non-null   float64
#  6   total sulfur dioxide  1359 non-null   float64
#  7   density               1359 non-null   float64
#  8   pH                    1359 non-null   float64
#  9   sulphates             1359 non-null   float64
#  10  alcohol               1359 non-null   float64
#  11  quality               1359 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 138.0 KB

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
#non-empty values for each feature
df.columns = [c.replace(' ', '_') for c in df.columns]
print('fixed acidity: ' + str(df.fixed_acidity.count()))
print('volatile acidity: ' + str(df.volatile_acidity.count()))
print('citric acid: ' + str(df.citric_acid.count()))
print('residual sugar: ' + str(df.residual_sugar.count()))
print('chlorides: ' + str(df.chlorides.count()))
print('free sulfur dioxide: ' + str(df.free_sulfur_dioxide.count()))
print('total sulfur dioxide: ' + str(df.total_sulfur_dioxide.count()))
print('density: ' + str(df.density.count()))
print('pH: ' + str(df.pH.count()))
print('sulphates: ' + str(df.sulphates.count()))
print('alcohol: ' + str(df.alcohol.count()))
print('quality: ' + str(df.quality.count()))
# Out:
# fixed acidity: 1359
# volatile acidity: 1359
# citric acid: 1359
# residual sugar: 1359
# chlorides: 1359
# free sulfur dioxide: 1359
# total sulfur dioxide: 1359
# density: 1359
# pH: 1359
# sulphates: 1359
# alcohol: 1359
# quality: 1359

# %%
print(df.nunique())
print()
print(df.dtypes)
# Out:
# fixed_acidity            96
# volatile_acidity        143
# citric_acid              80
# residual_sugar           91
# chlorides               153
# free_sulfur_dioxide      60
# total_sulfur_dioxide    144
# density                 436
# pH                       89
# sulphates                96
# alcohol                  65
# quality                   6
# dtype: int64
#
# fixed_acidity           float64
# volatile_acidity        float64
# citric_acid             float64
# residual_sugar          float64
# chlorides               float64
# free_sulfur_dioxide     float64
# total_sulfur_dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
#Data type Numeric?
print('fixed acidity: ' + str(pd.api.types.is_numeric_dtype(df.fixed_acidity)))
print('volatile acidity: ' + str(pd.api.types.is_numeric_dtype(df.volatile_acidity)))
print('citric acid: ' + str(pd.api.types.is_numeric_dtype(df.citric_acid)))
print('residual sugar: ' + str(pd.api.types.is_numeric_dtype(df.residual_sugar)))
print('chlorides: ' + str(pd.api.types.is_numeric_dtype(df.chlorides)))
print('free sulfur dioxide: ' + str(pd.api.types.is_numeric_dtype(df.free_sulfur_dioxide)))
print('total sulfur dioxide: ' + str(pd.api.types.is_numeric_dtype(df.total_sulfur_dioxide)))
print('density: ' + str(pd.api.types.is_numeric_dtype(df.density)))
print('pH: ' + str(pd.api.types.is_numeric_dtype(df.pH)))
print('sulphates: ' + str(pd.api.types.is_numeric_dtype(df.sulphates)))
print('alcohol: ' + str(pd.api.types.is_numeric_dtype(df.alcohol)))
print('quality: ' + str(pd.api.types.is_numeric_dtype(df.quality)))
# Out:
# fixed acidity: True
# volatile acidity: True
# citric acid: True
# residual sugar: True
# chlorides: True
# free sulfur dioxide: True
# total sulfur dioxide: True
# density: True
# pH: True
# sulphates: True
# alcohol: True
# quality: True

# %%
print('fixed acidity count: ' + str(df.fixed_acidity.count()))
print('fixed acidity min: ' + str(df.fixed_acidity.min()))
print('fixed acidity max: ' + str(df.fixed_acidity.max()))
print('fixed acidity quantile(.25): ' + str(df.fixed_acidity.quantile(.25)))
print('fixed acidity quantile(.50): ' + str(df.fixed_acidity.quantile(.50)))
print('fixed acidity quantile(.75): ' + str(df.fixed_acidity.quantile(.75)))
print('fixed acidity mean: ' + str(df.fixed_acidity.mean()))
print('fixed acidity median: ' + str(df.fixed_acidity.median()))
print('fixed acidity mode: ' + str(df.fixed_acidity.mode().values[0]))
# Out:
# fixed acidity count: 1359
# fixed acidity min: 4.6
# fixed acidity max: 15.9
# fixed acidity quantile(.25): 7.1
# fixed acidity quantile(.50): 7.9
# fixed acidity quantile(.75): 9.2
# fixed acidity mean: 8.310596026490067
# fixed acidity median: 7.9
# fixed acidity mode: 7.2

# %%
print('volatile acidity count: ' + str(df.volatile_acidity.count()))
print('volatile acidity min: ' + str(df.volatile_acidity.min()))
print('volatile acidity max: ' + str(df.volatile_acidity.max()))
print('volatile acidity quantile(.25): ' + str(df.volatile_acidity.quantile(.25)))
print('volatile acidity quantile(.50): ' + str(df.volatile_acidity.quantile(.50)))
print('volatile acidity quantile(.75): ' + str(df.volatile_acidity.quantile(.75)))
print('volatile acidity mean: ' + str(df.volatile_acidity.mean()))
print('volatile acidity median: ' + str(df.volatile_acidity.median()))
print('volatile acidity mode: ' + str(df.volatile_acidity.mode().values[0]))
# Out:
# volatile acidity count: 1359
# volatile acidity min: 0.12
# volatile acidity max: 1.58
# volatile acidity quantile(.25): 0.39
# volatile acidity quantile(.50): 0.52
# volatile acidity quantile(.75): 0.64
# volatile acidity mean: 0.5294775570272259
# volatile acidity median: 0.52
# volatile acidity mode: 0.5

# %%
print(df.std())
# Out:
# fixed_acidity            1.736990
# volatile_acidity         0.183031
# citric_acid              0.195537
# residual_sugar           1.352314
# chlorides                0.049377
# free_sulfur_dioxide     10.447270
# total_sulfur_dioxide    33.408946
# density                  0.001869
# pH                       0.155036
# sulphates                0.170667
# alcohol                  1.082065
# quality                  0.823578
# dtype: float64

# %%
df.fixed_acidity.std()
# Out:
# 1.736989807532466

# %%
import numpy as np
np.std(df.fixed_acidity, ddof=1)
# Out:
# 1.736989807532466

# %%
from scipy.stats import kurtosis, skew
print('Skew')
print(df.skew())
print('Kurtosis')
print(df.kurtosis())
# Out:
# Skew
# fixed_acidity           0.941041
# volatile_acidity        0.729279
# citric_acid             0.312726
# residual_sugar          4.548153
# chlorides               5.502487
# free_sulfur_dioxide     1.226579
# total_sulfur_dioxide    1.540368
# density                 0.044778
# pH                      0.232032
# sulphates               2.406505
# alcohol                 0.859841
# quality                 0.192407
# dtype: float64
# Kurtosis
# fixed_acidity            1.049673
# volatile_acidity         1.249243
# citric_acid             -0.788921
# residual_sugar          29.364592
# chlorides               38.624653
# free_sulfur_dioxide      1.892691
# total_sulfur_dioxide     4.042257
# density                  0.830659
# pH                       0.879790
# sulphates               11.102282
# alcohol                  0.159739
# quality                  0.340256
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.subplot()
sns.countplot(x='quality', data=df, hue='quality', palette='dark:purple')
plt.title('Distribution of Red Wine Quality')
plt.xlabel('Quality Score (3-8)')
plt.ylabel('Count')
# Interpretation: The dataset is unbalanced; most wines are rated 5 or 6, while excellent (8) or poor (3) wines are rare.
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.subplot()
sns.boxplot(x='quality', y='alcohol', hue='quality', data=df, palette='dark:purple')
plt.title('Alcohol Content by Wine Quality')
plt.xlabel('Quality Score')
plt.ylabel('Alcohol (%)')
# Interpretation: Higher quality wines (7 and 8) generally have a higher median alcohol content compared to lower quality wines.
# Out:
# Text(0, 0.5, 'Alcohol (%)')

# %%
plt.subplot()
sns.scatterplot(x='volatile_acidity', y='citric_acid', hue='quality', data=df, palette='coolwarm', alpha=0.6)
plt.title('Volatile Acidity vs. Citric Acid')
plt.xlabel('Volatile Acidity (Acetic Acid)')
plt.ylabel('Citric Acid')
# Interpretation: There is a negative correlation between Volatile Acidity and Citric Acid, higher quality wines (darker blue) tend to cluster where volatile
# acidity is lower and citric acid is higher.
# Out:
# Text(0, 0.5, 'Citric Acid')

# %%
plt.subplot()
correlation = df.corr()
sns.heatmap(correlation, annot=False, cmap='RdBu_r', center=0)
plt.title('Correlation Heatmap of Wine Features')
# Interpretation: This shows which variables move together. For instance,'fixed acidity' and 'pH' have a strong negative correlation (as expected),
# while 'alcohol' has the strongest positive correlation with 'quality'.
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap of Wine Features')
