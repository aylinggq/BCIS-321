# %% [markdown]
# **Objectives**
#
# The purpose of this checkpoint is to give you practice with using flow control. However, it will implement lessons learned in prior chapters as well.
#
# **Background**
#
# You are a medical researcher running a study on a new drug. You are screening potential participants and you need to make sure you identify any outliers. In particular, you want to flag anyone who is outside the typical ranges of tall/short or light/heavy. Therefore, write a simple routine to determine if a potential participant is eligible based on.
#
# 1. Weight
# 2. Height
# 3. Sex
#
# **Requirements**
#
# Collect these three data points through user input() boxes. Mark any that are outliers. Men within 62 inches and 80 inches tall and between 150 and 280 lbs are needed for this study. Women between 59 and 71 inches and 100 and 180 lbs are needed for this study. Create flow logic to determine whether an inputted patient is within the thresholds. If they are an outlier, print a message indicating they are not eligible and tell them which thresholds they did not meet. Create as many if/elif/else statements as you need to accomplish this task.
#
# In order to analyze data, we need to handle the many possible ways that these data could be entered. For example, sex could be entered into a textbox as "female", "f", "Female", 0, 1, "Male", "Man", "woman", or it could be mispelled. Use some combination of if/elif/else statements (including "or" and/or "and" criteria) and/or string formatting (e.g. converting case or examining only the first letter) to handle as many possibilities as you can think of to handle every type of input.
#
# For the height and weight, indicate that the user should enter numbers only. Using Python, check to see if a number is entered (i.e. not string/text data). If not, print a message stating that the user did not enter a number and ask them to start over.
#
# **Example Outputs:**
# * sex	height	weight	outlier?
# * m	82 inches	200 lbs	   yes: height
# * f	82 inches	2000 lbs	yes: height & weight
# * m	77 inches	200 lbs	   no
#
# **Other requirements:**
#
# Your table doesn't need to match the table format above exactly.
#
# There are many different ways to complete these requirements. You are not being tested to see if you use a particular method. Your code simply needs to meet the requirements above.

# %%
# Enter all of the code needed to answer this question in this code cell.
# Do not create any additional code cells before this cell or the auto-grader may have problems
# Start your code below:

# %%
my_gender=str(input("What is your gender?"))

if my_gender in("female"or"Woman"or"Female"or"woman"or"girl"or "girl"):
  gender= "female"
elif my_gender in ("male"or"Male"or"Man"or"man"or"boy"or"Boy"):
  gender="male"

my_height=input("What is your height in inches?")
try:
  height=float(my_height)
except:
  print("Invalid height. Try again.")

my_weight=input("What is your weight?")
try:
  weight=float(my_weight)
except:
  print("Invalid weight. Try again.")

outliers=[]

if gender=="male":
  if height<62 or height>80:
    outliers.append("height")
  if weight<150 or weight>280:
    outliers.append("weight")

elif gender=="female":
  if height<59 or height>71:
    outliers.append("height")
  if weight<100 or weight>180:
    outliers.append("weight")

if len(outliers)==0:
  print("Eligible for the study")
else:
  print("Not eligible in:", " and ".join(outliers))
# Out:
# What is your gender?f
# What is your height in inches?q
# Invalid height. Try again.
# What is your weight?50
# Not eligible in: height and weight
